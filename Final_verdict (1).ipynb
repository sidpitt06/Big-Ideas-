# %% [markdown]
# Best neighborhood
# We found the best neighborhood by summing up the bestness scores from our data sets.
# Summing up all of the points, we figured out that Squirrel Hill North is the best overall neighborhood, having, The saftery score being .92 and population overal best score being .91
