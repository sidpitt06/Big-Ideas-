# %% [markdown]
# Best neighborhood
# We found the best neighborhood by summing up the bestness scores from our data sets.
# Summing up all of the points, we figured out that Squirrel Hill North is the best overall neighborhood, having 1.83, a safety score being .92, and population overall best score being .91, and a housing stability score of .00126.

# %% [markdown]
# **Need to work on this** and show plots of the best neighborhoods, top 10, and the worst based on our metrics. We also need a
